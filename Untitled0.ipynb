# %% [markdown]
# <a href="https://colab.research.google.com/github/Robertbobby22/Python_Matplotlib_Pandas/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/soccer_venue PLOT.csv')

# %%
df.loc[:]
# Out:
#                 venue_name  aud_capacity
# 0        Stade de Bordeaux         42115
# 1   Stade Bollaert-Delelis         38223
# 2      Stade Pierre Mauroy         49822
# 3            Stade de Lyon         58585
# 4          Stade VElodrome         64354
# 5            Stade de Nice         35624
# 6         Parc des Princes         47294
# 7          Stade de France         80100
# 8  Stade Geoffroy Guichard         42000
# 9      Stadium de Toulouse         33150

# %%
x = df.venue_name
y = df.aud_capacity

# %%
plt.xticks(rotation=50, ha='right')
plt.bar(x, y, color=['black'])
plt.show()
